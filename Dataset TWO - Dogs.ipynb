# %% [markdown]
# # Homework 6, Part Two: A dataset about dogs.
#
# Data from [a FOIL request to New York City](https://www.muckrock.com/foi/new-york-city-17/pet-licensing-data-for-new-york-city-23826/)

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read in the file `NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx` and look at the first five rows

# %%
df = pd.read_excel('NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx')
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M               Unknown
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M               Unknown
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?
#
# If there are more than 30,000 rows in your dataset, go back and only read in the first 30,000.

# %%
df.shape
# Out:
# (81937, 15)

# %% [markdown]
# ## Describe the dataset in words. What is each row? List two column titles along with what each of those columns means.
#
# For example: “Each row is an animal in the zoo. `is_reptile` is whether the animal is a reptile or not”

# %% [markdown]
# Each row is an individual dog registration. Each column describes attributes of the dog i.e. gender, breed color

# %% [markdown]
# # Your thoughts
#
# Think of four questions you could ask this dataset. **Don't ask them**, just write them down in the cell below. Feel free to use either Markdown or Python comments.

# %% [markdown]
# 1. What is the most popular dog breed?
# 2. How old are the oldest dogs for each breed?
# 3. Are certain zip codes more likely to have their dog vaccinated?
# 4. What age are dogs most likely to be spayed

# %% [markdown]
# # Looking at some dogs

# %% [markdown]
# ## What are the most popular (primary) breeds of dogs? Graph the top 10.

# %%
df['Primary Breed'].value_counts().head(10)
# Out:
# Unknown                                 12894
# Yorkshire Terrier                        5133
# Shih Tzu                                 4727
# Chihuahua                                3924
# Maltese                                  2965
# Labrador Retriever                       2872
# American Pit Bull Terrier/Pit Bull       2153
# American Pit Bull Mix / Pit Bull Mix     2029
# Labrador Retriever Crossbreed            1864
# Beagle                                   1438
# Name: Primary Breed, dtype: int64

# %% [markdown]
# ## "Unknown" is a terrible breed! Graph the top 10 breeds that are NOT Unknown

# %%
df[df['Primary Breed'] == 'Unknown'].head(10)
# Out:
#     Owner Zip Code Animal Name Animal Gender Primary Breed  \
# 0            10024   BLUE MACK             M       Unknown
# 3            10025       Buddy             M       Unknown
# 9            10013  IAN                    M       Unknown
# 20           10025       Sarah             F       Unknown
# 29           10011  OTIS                   F       Unknown
# 30           10011    Logan                M       Unknown
# 33           10028       ROSIE             F       Unknown
# 38           11209     JASMINE             F       Unknown
# 56           10467  PEPI                   M       Unknown
# 58           10024       Louie             M       Unknown
#
#               Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0               AIREDALE TERR                 BROWN                  BLACK
# 3                    Cockapoo                 BLOND                  WHITE
# 9             GREYHOUND TER X                 WHITE                  BLACK
# ...

# %% [markdown]
# ## What are the most popular dog names?

# %%
df['Animal Name'].value_counts()
# Out:
# UNKNOWN           742
# Bella             527
# Max               515
# Charlie           403
# Lola              387
#                  ...
# Toki                1
# Suga Momma          1
# Isabella Cruz       1
# Chuchee             1
# MISO                1
# Name: Animal Name, Length: 29677, dtype: int64

# %% [markdown]
# ## Do any dogs have your name? How many dogs are named "Max," and how many are named "Maxwell"?

# %%
df[df['Animal Name'] == 'Conor']
# Out:
#        Owner Zip Code Animal Name Animal Gender       Primary Breed  \
# 6102            10011       Conor             M           Chihuahua
# 50154           10009       Conor             M             Unknown
# 71342           10011       Conor             M  Miniature Pinscher
#
#       Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 6102              NaN                   Tan                  White
# 50154  Lab/Beagle Mix                  RUST                    NaN
# 71342             NaN                 Brown                  Cream
#
#       Animal Third Color Animal Birth Spayed or Neut Guard or Trained  \
# 6102                 NaN   2013-04-01            Yes              NaN
# 50154                NaN   2010-12-01            Yes               No
# 71342                NaN   2013-02-01            Yes              NaN
#
#       Vaccinated        Application Date License Issued Date  \
# 6102         Yes 2015-05-06 09:25:17.223          2015-05-06
# ...

# %%
names = ['Max', 'Maxwell']

df[df['Animal Name'].isin(names)]
# Out:
#        Owner Zip Code Animal Name Animal Gender  \
# 42              10023         Max             M
# 53              10029         Max             M
# 128             11218         Max             M
# 174             11361         Max             M
# 425             10075         Max             M
# ...               ...         ...           ...
# 81608           10023         Max             M
# 81643           11372         Max             M
# 81677           11207         Max             M
# 81805           11106         Max             M
# 81935           10310         Max             M
#
#                               Primary Breed Secondary Breed  \
# 42                   Dachshund, Long Haired             NaN
# 53     American Pit Bull Mix / Pit Bull Mix             NaN
# 128                                 Unknown     Maltese Mix
# 174                 West High White Terrier             NaN
# 425                                 Unknown   Dachshund
# ...

# %% [markdown]
# ## What percentage of dogs are guard dogs?
#
# Check out the documentation for [value counts](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html).

# %%
df['Guard or Trained'].value_counts(normalize = True) * 100
# Out:
# No     99.897128
# Yes     0.102872
# Name: Guard or Trained, dtype: float64

# %% [markdown]
# ## What are the actual numbers?

# %%
df[df['Guard or Trained'] == "Yes"]['Animal Name'].count()
# Out:
# 51

# %%
df[df['Guard or Trained'] == "No"]['Animal Name'].count()
# Out:
# 49459

# %% [markdown]
# ## Wait... if you add that up, is it the same as your number of rows? Where are the other dogs???? How can we find them??????
#
# Use your `.head()` to think about it, then you'll do some magic with `.value_counts()`

# %%
df['Guard or Trained'].value_counts(dropna= False)
# Out:
# No     49525
# NaN    32361
# Yes       51
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## Fill in all of those empty "Guard or Trained" columns with "No"
#
# Then check your result with another `.value_counts()`

# %%
df['Guard or Trained'] = df['Guard or Trained'].replace({
    np.nan: "No"
})
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M               Unknown
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M               Unknown
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %% [markdown]
# ## What are the top dog breeds for guard dogs?

# %%
df_vax = df[df['Guard or Trained'] == 'Yes']

df_vax.groupby('Primary Breed').count().sort_values(by='Animal Name', ascending=False).head()
# Out:
#                                       Owner Zip Code  Animal Name  \
# Primary Breed
# Unknown                                           11           11
# German Shepherd Dog                                4            4
# American Pit Bull Mix / Pit Bull Mix               3            3
# Chihuahua                                          3            3
# Labrador Retriever                                 3            3
#
#                                       Animal Gender  Secondary Breed  \
# Primary Breed
# Unknown                                          11               11
# German Shepherd Dog                               4                0
# American Pit Bull Mix / Pit Bull Mix              3                0
# Chihuahua                                         3                0
# Labrador Retriever                                3                0
#
#                                       Animal Dominant Color  \
# Primary Breed
# ...

# %% [markdown]
# ## Create a new column called "year" that is the dog's year of birth
#
# The `Animal Birth` column is a datetime, so you can get the year out of it with the code `df['Animal Birth'].apply(lambda birth: birth.year)`.

# %%
df['year'] = df['Animal Birth'].apply(lambda birth: birth.year)

# %% [markdown]
# ## Calculate a new column called “age” that shows approximately how old the dog is. How old are dogs on average?

# %%
df['age'] = 2021 - df['year']

# %%
df['age'].mean()
# Out:
# 11.341848005174707

# %% [markdown]
# # Joining data together

# %% [markdown]
# ## Which neighborhood does each dog live in?
#
# You also have a (terrible) list of NYC neighborhoods in `zipcodes-neighborhoods.csv`. Join these two datasets together, so we know what neighborhood each dog lives in. **Be sure to not read it in as `df`, or else you'll overwrite your dogs dataframe.**

# %%
df_zips = pd.read_csv('zipcodes-neighborhoods.csv')
df_zips.head()
# Out:
#              neighborhood    zip borough
# 0           Central Bronx  10453   Bronx
# 1           Central Bronx  10457   Bronx
# 2           Central Bronx  10460   Bronx
# 3  Bronx Park and Fordham  10458   Bronx
# 4  Bronx Park and Fordham  10467   Bronx

# %%
df = df.merge(df_zips, left_on='Owner Zip Code', right_on='zip')
df.head()
# Out:
#    Owner Zip Code Animal Name Animal Gender                     Primary Breed  \
# 0           10024   BLUE MACK             M                           Unknown
# 1           10024       Louie             M                           Unknown
# 2           10024       Tosha             F               Collie, Smooth Coat
# 3           10024     Poppett             F  Dachshund, Long Haired Miniature
# 4           10024      Harlen             M                           Unknown
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1       Coonhound                 Black                  White
# 2             NaN            BLUE MERLE                  WHITE
# 3             NaN                 Black                  Brown
# 4     Plott Hound                 BLACK                    TAN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# ...

# %% [markdown]
# ## What is the most popular dog name in all parts of the Bronx? How about Brooklyn? The Upper East Side?

# %%
df[df.borough == "Bronx"]['Animal Name'].value_counts().head()
# Out:
# Rocky       60
# Max         56
# Bella       54
# Lucky       51
# Princess    43
# Name: Animal Name, dtype: int64

# %% [markdown]
# ## What is the most common dog breed in each of the neighborhoods of NYC?

# %%
df.groupby('borough_y')['Primary Breed'].value_counts().groupby(level=0).nlargest(5)
# Out:
# borough_y      borough_y      Primary Breed
# Bronx          Bronx          Unknown                               1121
#                               Yorkshire Terrier                      753
#                               Shih Tzu                               682
#                               Chihuahua                              553
#                               American Pit Bull Terrier/Pit Bull     442
# Brooklyn       Brooklyn       Unknown                               3067
#                               Yorkshire Terrier                     1316
#                               Shih Tzu                              1236
#                               Chihuahua                              987
#                               Labrador Retriever                     655
# Manhattan      Manhattan      Unknown                               4392
#                               Yorkshire Terrier                     1402
# ...

# %% [markdown]
# ## What breed of dogs are the least likely to be spayed? Male or female?

# %%
df_spayed = df[df['Spayed or Neut'] == "Yes"]
df_spayed.groupby('Primary Breed')['Animal Gender'].value_counts().groupby(level=0).nlargest(5).sort_values(ascending=True)
# Out:
# Primary Breed        Animal Gender
# Kuvasz               F                   1
# Sussex Spaniel       F                   1
# Bracco Italiano      M                   1
# English Toy Spaniel  F                   1
# Berger Picard        M                   1
#                                       ...
# Chihuahua            M                1622
# Yorkshire Terrier    M                1955
# Shih Tzu             M                1969
# Unknown              F                5803
#                      M                5850
# Name: Animal Gender, Length: 511, dtype: int64

# %% [markdown]
# ## Make a new column called monochrome that is True for any animal that only has black, white or grey as one of its colors. How many animals are monochrome?

# %%
color = ['black', 'BLACK', 'Black', "white", "WHITE", 'White', 'brown', 'BROWN', 'Brown']

df['monochrome'] = df['Animal Dominant Color'].isin(color)
df['monochrome']
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 80854     True
# 80855     True
# 80856    False
# 80857     True
# 80858    False
# Name: monochrome, Length: 80859, dtype: bool

# %% [markdown]
# ## How many dogs are in each borough? Plot it in a graph.

# %%
df.groupby('borough_y')['Animal Name'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='borough_y'>

# %% [markdown]
# ## Which borough has the highest number of dogs per-capita?
#
# You’ll need to merge in `population_boro.csv`

# %%
df_pop = pd.read_csv('boro_population.csv')
df_pop.head()
# Out:
#          borough  population  area_sqmi
# 0      Manhattan     1644518         23
# 1          Bronx     1455444         42
# 2       Brooklyn     2636735         71
# 3         Queens     2339150        109
# 4  Staten Island      474558         59

# %%
df = df.merge(df_pop, left_on='borough', right_on='borough')
df.head()
# Out:
#    Owner Zip Code Animal Name Animal Gender                     Primary Breed  \
# 0           10024   BLUE MACK             M                           Unknown
# 1           10024       Louie             M                           Unknown
# 2           10024       Tosha             F               Collie, Smooth Coat
# 3           10024     Poppett             F  Dachshund, Long Haired Miniature
# 4           10024      Harlen             M                           Unknown
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1       Coonhound                 Black                  White
# 2             NaN            BLUE MERLE                  WHITE
# 3             NaN                 Black                  Brown
# 4     Plott Hound                 BLACK                    TAN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# ...

# %%
df_ex = pd.DataFrame(df.groupby('borough')['Animal Name'].count())
df_ex.iloc[:, 0]
# Out:
# borough
# Bronx             7941
# Brooklyn         19726
# Manhattan        28492
# Queens           16631
# Staten Island     7876
# Name: Animal Name, dtype: int64

# %% [markdown]
# ## Make a bar graph of the top 5 breeds in each borough.
#
# How do you groupby and then only take the top X number? You **really** should ask me, because it's kind of crazy.

# %%
df.groupby('borough')['Primary Breed'].value_counts().groupby(level=0).nlargest(5).sort_values(ascending=True).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='borough,borough,Primary Breed'>

# %% [markdown]
# ## What percentage of dogs are not guard dogs?

# %%
df['Guard or Trained'].value_counts(normalize=True) * 100
# Out:
# No     99.899931
# Yes     0.100069
# Name: Guard or Trained, dtype: float64
